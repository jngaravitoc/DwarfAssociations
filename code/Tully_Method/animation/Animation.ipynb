# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
i = 30
j = 3
to_frame = j
from_frame = i

# %%
while i>j:
    if i>9:
        data = np.loadtxt("../data-sppedy2/test000" + str(i) + ".txt")
    elif i<10:
        data = np.loadtxt("../data-sppedy2/test0000" + str(i) + ".txt")
    x = data[:,0]
    y = data[:,1]
    plt.scatter(x, y, s=60, alpha=0.75, c='r')
    plt.scatter(x[-1], y[-1], s=60, c='g')
    plt.xlim([14, 30])
    plt.ylim([24, 42])
    if from_frame-i<10:
        plt.savefig("tully-method0" + str(from_frame-i)+ ".png")
    else:
        plt.savefig("tully-method" + str(from_frame-i)+ ".png")

    plt.close()
    i-=1

# %%
# !lsls
ls
# Out:
# Animation.ipynb  test00835.txt	test01669.txt  test02503.txt  test03337.txt  test04171.txt  test05005.txt
# test00002.txt	 test00836.txt	test01670.txt  test02504.txt  test03338.txt  test04172.txt  test05006.txt
# test00003.txt	 test00837.txt	test01671.txt  test02505.txt  test03339.txt  test04173.txt  test05007.txt
# test00004.txt	 test00838.txt	test01672.txt  test02506.txt  test03340.txt  test04174.txt  test05008.txt
# test00005.txt	 test00839.txt	test01673.txt  test02507.txt  test03341.txt  test04175.txt  test05009.txt
# test00006.txt	 test00840.txt	test01674.txt  test02508.txt  test03342.txt  test04176.txt  test05010.txt
# test00007.txt	 test00841.txt	test01675.txt  test02509.txt  test03343.txt  test04177.txt  test05011.txt
# test00008.txt	 test00842.txt	test01676.txt  test02510.txt  test03344.txt  test04178.txt  test05012.txt
# test00009.txt	 test00843.txt	test01677.txt  test02511.txt  test03345.txt  test04179.txt  test05013.txt
# ...
