# %%
# %pylab inline
rcParams['figure.figsize'] = 10, 10
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = np.loadtxt("../data/Distances/potenciales.txt")

# %%
shape(data)
# Out:
# (18418, 4)

# %%
x = data[:,0]
y = data[:,1]
z = data[:,2]
u = data[:,3]

# %%
print amax(u), amin(u)
# Out:
# 3.65073752363e+27 1.39552921889e+22

# %%
U = log(u)

print amax(U), amin(U)
# Out:
# 63.4647267193 50.9901457576

# %%
index = where(U>60)
U = U[index]
X = x[index]
Y = y[index]
Z = z[index]
print len(U)
# Out:
# 81

# %%
plt.scatter(x/10., y/10., s=0.5)
plt.scatter(X/10., Y/10., s=18.5, c = 'r' )
plt.xlim([1, 3.5])
plt.ylim([2, 4])
# Out:
# (2, 4)

# %%
print U[0:10]
print X[0:10]
# Out:
# [ 62.0438848   61.56702626  61.58558442  61.11737294  61.08909168
#   60.28067974  60.22080637  60.20050705  60.03238555  63.46472672]
# [ 20.00976926  21.13954565  16.9059058   22.01056101  19.97672752
#   19.89115828  20.17562766  20.19674983  21.6556776   21.59029193]

# %%
scatter(x, -log(u))

# %%
scatter(y, -log(u))

# %%
scatter(z, -log(u))

# %% [raw]
# Los sub-halos con potenciales mayores a -57 estan en la region mas concentrada de GL, y estos valores corresponden a que sus potenciales se anulan mas o menos son puntos de Lagrange.

# %%
V = -log(u)
index = np.where(V<-57)
XX = x[index]
YY = y[index]
ZZ = z[index]
VV = V[index]

# %%
scatter(x, y,  c = 'r', s=4)
scatter(XX, YY, s = 0.1)
print len(XX)
print len(x)
# Out:
# 2012
# 18418

# %%
scatter(XX, VV)

# %%
XS = sort(XX)
# Out:
# array([  2.81016600e-02,   6.39194200e-02,   7.75851700e-02, ...,
#          6.39294912e+01,   6.39782412e+01,   6.39792114e+01])
