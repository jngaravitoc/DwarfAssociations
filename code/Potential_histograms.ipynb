# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = np.loadtxt("../data/Distances/potenciales.txt")

# %%
x = data[:, 0]
y = data[:, 1]
z = data[:, 2]
u = data[:, 3]

# %%
plt.scatter(x, y, s=0.1)
xlim([15, 30])
ylim([23, 40])
# Out:
# (23, 40)

# %%
ymin = min(y)
xmin = min(x)
xmax = max(x)
ymax = max(y)

# %%
fig = figure(num=None, figsize=(19, 19.5))
#plt.scatter(x, y, s=1)
aspectratio = 1.0*(max(x) - min(x))/(1.0*max(y) - min(y))
hist,xedges,yedges = numpy.histogram2d(x,y,bins=(50,50), weights=u,range=[[ymin,ymax],[xmin,xmax]])
plt.hexbin(x, y, u, gridsize=20000, bins=20)
#hist = hist.transpose()
#my_extent = (xedges[0], xedges[-1], yedges[0], yedges[-1])
#imshow(log(hist),extent=[xmin, xmax, ymax, ymin], interpolation='nearest', aspect=aspectratio)
plt.xlabel("$x$", fontsize = 30)
plt.ylabel("$y$", fontsize = 30)
#colorbar(shrink = 0.55)
plt.xlim(10, 35)
plt.ylim(24, 42)
plt.show()
plt.savefig("LGpotential.png")

# %%
fig = figure(num=None, figsize=(19, 19.5))
cs = contour(log(hist), origin='lower',levels = np.linspace(55, 60, 5), extent=[xmin, xmax, ymax, ymin])
plt.clabel(cs, fontsize=19)
plt.xlim(10, 35)
plt.ylim(24, 42)
# Out:
# (24, 42)

# %%
fig = figure(num=None, figsize=(9, 9.5))
x, y = histogram(log(u), bins=60)
plt.plot(y[:-1], x)
print len(x), len(y)
# Out:
# 60 61

# %%
min(log(u))
# Out:
# 50.990145757580272
