# %% [markdown]
# ## To do:
#
# 1. Make 3d plots for all the halos associations and  galaxies associations
# 2. Plot the dispersions for every group

# %%
import plotly.plotly as py
from plotly.graph_objs import *
from functions import threedplot
from functions import dispersiones
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/jngaravito57/Documents/codes/ipython/IPython/kernel/__init__.py:10: UserWarning:
#
# The `IPython.kernel` package has been deprecated. You should import from ipython_kernel or jupyter_client instead.
#
# WARNING: pylab import has clobbered these variables: ['Annotation', 'Figure']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
py.sign_in('xozidok', '7npyt3xzbf')

# %%
snap_fof = "FOFDMIllustris_group_35.dat"

# %%
x0, y0, z0 = threedplot(snap_fof , 0)
x1, y1, z1 = threedplot(snap_fof , 1)
x2, y2, z2 = threedplot(snap_fof , 2)
x3, y3, z3 = threedplot(snap_fof , 3)
x4, y4, z4 = threedplot(snap_fof , 4)
x5, y5, z5 = threedplot(snap_fof , 5)
x6, y6, z6 = threedplot(snap_fof , 6)
x7, y7, z7 = threedplot(snap_fof , 7)
x8, y8, z8 = threedplot(snap_fof , 8)
x9, y9, z9 = threedplot(snap_fof , 9)
x10, y10, z10 = threedplot(snap_fof , 10)
x11, y11, z11 = threedplot(snap_fof , 11)
x12, y12, z12 = threedplot(snap_fof , 12)
x13, y13, z13 = threedplot(snap_fof , 13)
x14, y14, z14 = threedplot(snap_fof , 14)
x15, y15, z15 = threedplot(snap_fof , 15)
x16, y16, z16 = threedplot(snap_fof , 16)

# %%
trace0 = Scatter3d(
   x = x0, y = y0, z = z0,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['rgba(217, 217, 217, 0.14)'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace1 = Scatter3d(
   x = x1, y = y1, z = z1,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace2 = Scatter3d(
   x = x2, y = y2, z = z2,
   mode='markers',
   marker=Marker(
        size=3,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace3 = Scatter3d(
   x = x3, y = y3, z = z3,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace4 = Scatter3d(
   x = x4, y = y4, z = z4,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace5 = Scatter3d(
   x = x5, y = y5, z = z5,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace6 = Scatter3d(
   x = x6, y = y6, z = z6,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

trace7 = Scatter3d(
   x = x7, y = y7, z = z7,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace8 = Scatter3d(
   x = x8, y = y8, z = z8,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace9 = Scatter3d(
   x = x9, y = y9, z = z9,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace10 = Scatter3d(
   x = x10, y = y10, z = z10,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace11 = Scatter3d(
   x = x11, y = y11, z = z11,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace12 = Scatter3d(
   x = x12, y = y12, z = z12,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace13 = Scatter3d(
   x = x13, y = y13, z = z13,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace14 = Scatter3d(
   x = x14, y = y14, z = z14,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace15 = Scatter3d(
   x = x15, y = y15, z = z15,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)
trace16 = Scatter3d(
   x = x16, y = y16, z = z16,
   mode='markers',
   marker=Marker(
        size=6,
        line=Line(
            color=['r'],
            width=0.5
        ),
        opacity=0.8
    )
)

data = Data([trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10, 
            trace11, trace12, trace13, trace14, trace15, trace16])
layout = Layout(
    title=snap_fof,
    margin=Margin(
        l=0,
        r=0,
        b=0,
        t=0
    )
)

fig = Figure(data=data, layout=layout)

# %%
py.iplot(fig, filename='group1.png')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~xozidok/232.embed" height="525" width="100%"></iframe>

# %%
dispersiones(snap_fof)
# Out:
# ([608.08033405284459,
#   113.05163257814209,
#   61.876149467562286,
#   0.0,
#   92.042114594591624,
#   136.64765162076367,
#   116.72533484306749,
#   95.097420166831398,
#   126.54272027128088,
#   3.246736243585112e-12,
#   2.0606229360689233e-12,
#   47.411589924484161,
#   1.4637870187718921e-12,
#   0.57293440415375085,
#   43.633199943029567,
#   4.9032597357512817e-13],
#  [42.95233291775245,
#   23.666244785624119,
#   13.316616732704883,
#   5.3290705182007514e-15,
#   15.101952295171008,
#   5.5107086917354513,
#   5.360154951012599,
#   3.2372513748102376,
#   11.169345458830868,
#   1.2434497875801753e-14,
#   8.8817841970012523e-16,
#   5.1516040010755715,
#   7.9936057773011271e-15,
#   6.4943373083141989,
#   2.071356812187557,
#   2.4980264769075375e-14],
#  [63.500954112138473,
#   3.246736243585112e-12,
#   92.503025549010417,
#   2.0606229360689233e-12,
#   105.15350743942305],
#  [14.579166901321607,
#   1.2434497875801753e-14,
#   2.2223670996290221,
#   8.8817841970012523e-16,
#   2.7498228384514896])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(111, projection='3d')
data_min = np.loadtxt("data/A_min" + snap_fof)
x_min = data_min[:,0]
y_min = data_min[:,1]
z_min = data_min[:,2]
N_min = data_min[:,6]
xyc = range(int(min(list(set(N_min)))),int(max(list(set(N_min)))+1))
for i in range(int(min(list(set(N_min)))),int(max(list(set(N_min)))+1)):
                index = np.where(N_min==i)
                index = index[0]
                #print "index=", len(index)
                if (len(index)<50):
                        x_LLmin = x_min[index]
                        y_LLmin = y_min[index]
                        z_LLmin = z_min[index]
                        ax.scatter(x_LLmin, y_LLmin, z_LLmin, c=(random.random(), random.random(), random.random()), s=30, alpha=0.6,  label="group" + str(i))
title(snap_fof, fontsize=20)
legend(loc="center left")
plt.show()
plt.close()

# %%
scatter(x_LLmin, y_LLmin, s=5)

# %% [raw]
# help(scatter)

# %%
scatter?

# %%
np.ones([2,1])
# Out:
# array([[ 1.],
#        [ 1.]])
