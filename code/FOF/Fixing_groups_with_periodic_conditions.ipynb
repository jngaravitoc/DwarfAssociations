# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.loadtxt("../../data/Illustris/Illustris_group_7.dat")
ID = data[:,0]
x = data[:,1]
y = data[:,2]
z = data[:,3]
vx = data[:,4]
vy = data[:,5]
vz = data[:,6]
Vmax = data[:,7]
B = data[:,8]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

index = where(x>50000)
index = index[0]
index2 = where(x<=50000)
index2 = index2[0]

ax.scatter(x[index]-30000, y[index], z[index])
ax.scatter(x[index2]+45000, y[index2], z[index2])
"""

ax.scatter(x, y, z)
#"""
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

#print B[index2]

# %%
f = open("../../data/Illustris/Illustris_group_7.dat", "w")
f.write("#subID    x  y  z  vx  yv  yz  vmax   B_MAG \n")
f.write("#subID  kpc/h  kpc/h  kpc/h  km/s   km/s   km/s   km/s   mags \n")
for i in range(len(x[index])):
    f.write(("%f \t %f \t %f \t %f \t %f \t %f \t %f \t %f \t %f \n")%(ID[index[i]], x[index[i]]-30000, y[index[i]], z[index[i]], vx[index[i]], vy[index[i]], vz[index[i]], Vmax[index[i]], B[index[i]]))
for i in range(len(x[index2])):
    f.write(("%f \t %f \t %f \t %f \t %f \t %f \t %f \t %f \t %f \n")%(ID[index2[i]], x[index2[i]]+45000, y[index2[i]], z[index2[i]], vx[index2[i]], vy[index2[i]], vz[index2[i]], Vmax[index2[i]], B[index2[i]]))
f.close()

# %%
x[index[1]]-30000
# Out:
# 44731.3125
